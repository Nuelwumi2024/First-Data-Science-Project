# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#data import
stdnt = pd.read_csv("C:/Users/PC/Documents/Student_Performance.csv")

# %%
stdnt.head(10)
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
# 5              3               78                         No            9
# 6              7               73                        Yes            5
# 7              8               45                        Yes            4
# 8              5               77                         No            8
# 9              4               89                         No            4
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# ...

# %%
# information on data set 
stdnt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
# show the rows and columns respectively
stdnt.shape
# Out:
# (10000, 6)

# %%
# descriptive analysis
stdnt.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
stdnt.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
#showing how many of unique values for the string column
nunique_Extracurricular_Activities = stdnt["Extracurricular Activities"].nunique()
print(nunique_Extracurricular_Activities)
# Out:
# 2

# %%
#showing the two result in the string column
unique = stdnt["Extracurricular Activities"].unique()
print(unique)
# Out:
# ['Yes' 'No']

# %%
#converting the sring c0lumn into integer
convert_Extracurricular_Activities = {'Yes':1,'No':0}
stdnt["Extracurricular Activities"] = stdnt["Extracurricular Activities"].map(convert_Extracurricular_Activities)

# %%
stdnt.tail(10)
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 9990              9               43                           0            7
# 9991              5               97                           1            7
# 9992              9               52                           0            9
# 9993              9               58                           1            7
# 9994              6               46                           1            8
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
#       Sample Question Papers Practiced  Performance Index
# ...

# %%
stdnt.describe()
# Out:
#        Hours Studied  Previous Scores  Extracurricular Activities  \
# count   10000.000000     10000.000000                10000.000000
# mean        4.992900        69.445700                    0.494800
# std         2.589309        17.343152                    0.499998
# min         1.000000        40.000000                    0.000000
# 25%         3.000000        54.000000                    0.000000
# 50%         5.000000        69.000000                    0.000000
# 75%         7.000000        85.000000                    1.000000
# max         9.000000        99.000000                    1.000000
#
#         Sleep Hours  Sample Question Papers Practiced  Performance Index
# count  10000.000000                      10000.000000       10000.000000
# mean       6.530600                          4.583300          55.224800
# std        1.695863                          2.867348          19.212558
# min        4.000000                          0.000000          10.000000
# ...

# %%
# visualization of dataset - those that didn't get involved in extracurricular activities vs those who did
sns.countplot(x=stdnt["Extracurricular Activities"],data=stdnt);

# %%
correlate_category = stdnt.corr()

# %%
#plotting the correlation matrix
plt.figure(figsize=(7,7))
sns.heatmap(correlate_category, annot=True, linewidths=1, cmap="coolwarm")
plt.title("Correlation Matrix")
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
sns.pairplot(data=stdnt)

# %%
#Dependent variable
stdnt["Performance Index"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
#saved up the new data set
stdnt.to_csv("my new stdnt.csv")
